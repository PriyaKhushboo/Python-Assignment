# %%
1. What are escape characters, and how do you use them?
Ans:-In python backslash i.e,(\) along with some specific character is called as escape character.we can use as \n for new 
    line, \r for carriage return, \b for backspace, \t for tab space,etc. we can use them according to our need in program.

# %%
2. What do the escape characters n and t stand for?
Ans:-n is used for a new line and t is used to give a space same as tab.

# %%
3. What is the way to include backslash characters in a string?
Ans:-The way to include backslash character in string then we have to keep in mind that it should not be combined with the 
    escape character and if that will be the case then we should always put double backslash to avoid errors.

# %%
4. The string "Howl's Moving Castle" is a correct value. Why isn't the single quote character in the word Howl's not escaped a problem?
Ans:-If we will put single quote then it would be syntax error as we are using single quote in between so we will have to use
     double quote for enclosing the string or else we could write it as 'Howl\'s Moving Castle' by putting backslash.

# %%
5. How do you write a string of newlines if you don't want to use the n character?
Ans:-we can use os.linesep by importing os as new line character when we don't want to use the n character.
    ex-
import os
s = 'sweet'+ os.linesep + 'khushi'
print(s)

# %%
6. What are the values of the given expressions?
'Hello, world!'[1]
'Hello, world!'[0:5]
'Hello, world!'[:5]
'Hello, world!'[3:]

Ans:-
e
Hello
Hello
lo, world!

# %%
7. What are the values of the following expressions?
'Hello'.upper()
'Hello'.upper().isupper()
'Hello'.upper().lower()

Ans:-
HELLO
True
hello

# %%
8. What are the values of the following expressions?
'Remember, remember, the fifth of July.'.split()
'-'.join('There can only one.'.split())

Ans:-
['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']
There-can-only-one.

# %%
9. What are the methods for right-justifying, left-justifying, and centering a string?
Ans:-The method for right-justifying is rjust(), the method for left-justifying is ljust() and for centering is center().

# %%
10. What is the best way to remove whitespace characters from the start or end?
Ans:-strip() is the function which is used to remove whitespaces from the start or end.

# %%
import os
keyword = 'physical'+ os.linesep + 'distancing'
print(keyword)
# Out:
# physical
# distancing

# %%
s='sweet'+os.linesep+'khushi'
