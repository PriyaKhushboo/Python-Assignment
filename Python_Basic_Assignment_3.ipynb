# %%
1. Why are functions advantageous to have in your programs?

ANs:-Functions are advantageous to have in program as:-
     1. It avoids repetition of code in program
     2. It increases readability and clarity of our code
     3. It reduces chances of error to occur in program
     4. It divides a complex program into simpler one

# %%
2. When does the code in a function run: when it's specified or when it's called?

Ans:-The code in a function run when it is called.

# %%
3. What statement creates a function?

Ans:-The keyword named 'def' is used to create function

# %%
4. What is the difference between a function and a function call?

Ans:-A function is a block of code to carry out a specific task whereas a function call is used to invoke the particular 
    function. 
    A function is a procedure to achieve a particular task to be done whereas the function call is using the
    function to achive that task.

# %%
5. How many global scopes are there in a Python program? How many local scopes?

Ans:-There is only one global scope in a python program. The scope exists only until the program terminates.
     A local variable is something which has limited scope and it exists only within the block that it is declared in.

# %%
6. What happens to variables in a local scope when the function call returns?
Ans:-Local variables are destroyed when the function call returns.

# %%
7. What is the concept of a return value? Is it possible to have a return value in an expression?

Ans:-Return statement is used to end the execution of the function and try to always return the result.
     Yes, it is possible to have a return value in an expression as expression will always returns the value by default.

# %%
8. If a function does not have a return statement, what is the return value of a call to that function?

Ans:-If a function does not specify a return value then it returns None

# %%
9. How do you make a function variable refer to the global variable?

Ans:-we can use the global keyword to declare that specific variable as global.

# %%
10. What is the data type of None?

Ans:-It is of NoneType.

# %%
11. What does the sentence import areallyourpetsnamederic do?

Ans:-It will import a module named areallyourpetsnamederic.

# %%
12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

Ans:-spam.bacon()

# %%
13. What can you do to save a programme from crashing if it encounters an error?

Ans:-we can use try and except block to handle the error.

# %%
14. What is the purpose of the try clause? What is the purpose of the except clause?

Ans:-try clause simply will try to execute the code and if it is unable to execute due to error and is supposed to throw an
    error then except clause except that error or handles that error and we could print that error as well.
