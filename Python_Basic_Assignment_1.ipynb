# %%
1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.

* :- expression
'hello' :- values
-87.8 :- values
- :- expression
/ :- expression
+:- expression
6 :- values

# %%
2. What is the difference between string and variable?

Ans:- A variable is something in which we could store our data and use that variable anywhere in the specific program and 
    string is something which we write inside single quotes or double quotes. 
Example of variable:-  a = 24, where a is the variable 
String example:- “khushbu”, “24”

# %%
3. Describe three different data types.

Ans:-1. Numeric in which we can get integer, float and complex number.ex- 24, 24.5, 3+4j
     2.Sequence type in which we can get string, list and tuple, ex- 'khushi', [2,3,5,'khushi',8], (2,3,5,7)
    3.Dictionary:- here we can find elements in key and value pair. ex- {'name': 'khushi', 'age' : '25', 'roll' :'23'}

# %%
4. What is an expression made up of? What do all expressions do?

Ans:- An expression is something which is a combination of constants, variables and operators that evaluates to a single
     value. All expression returns the values.

# %%
5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

Ans:-Expression is something which will always returns the value and we can print it whereas statement never returns any
     value and can not print any result
        example of expression= 'happy'+'world'
        example of statement= loops, conditional branching etc.

# %%
6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1

Ans:-22

# %%
7. What should the values of the following two terms be?
'spam' + 'spamspam'
'spam' * 3

Ans:-'spamspamspam'
     'spamspamspam'

# %%
8. Why is eggs a valid variable name while 100 is invalid?

Ans:-100 is a invalid variable name as we can not start a variable name with integer.

# %%
9. What three functions can be used to get the integer, floating-point number, or string version of a value?

Ans:-the three function which can be used to get the integer, floating-point number, or string version of a value is
    int(), float(), str()

# %%
10. Why does this expression cause an error? How can you fix it?
'I have eaten ' + 99 + ' burritos.'

Ans:- This expression causes an error as we can not concatinate the string with integer. 
     we can fix this issue by keeping 99 under single or double quotes
    'I have eaten ' + '99' + ' burritos.'
