# %%
1.Write a Python program to print "Hello Python"?
Ans:-
print("Hello Python")

# %%
2.Write a Python program to do arithmetical operations addition and division.?
Ans:-
For Addition:
num1=5
num2=10
sum=num1+num2
print('The addition of {} and {} is'.format(num1,num2),sum)

For division:
num1=10
num2=5
div=num1/num2
print('The division of {} and {} is'.format(num1,num2),div)

# %%
3.Write a Python program to find the area of a triangle?
Ans:-
def area(b,h):
    return(1/2*(b*h))

After writing above program call function
area(4,8)

# %%
4.Write a Python program to swap two variables?
Ans:-
a=2
b=4
print(a,b)
c=0
c=a
a=b
b=c
print(a,b)

# %%
5.Write a Python program to generate a random number?
Ans:-For generating random number we need to import random module

import random
random.randint(1,10)
